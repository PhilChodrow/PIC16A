# %%
#We didn't do same id for numbers so make sure to do it here

# %% [markdown]
# __Lists:__
#
# - A list is a collection of objects in order
# - Somewhat similar to arrays in C++, but more also very different
# - There are many types list-like items in python, we call these items __iterables__

# %%
L=['a','b','c','d']

# %%
print(L[0],L[1],L[2])
# Out:
# a b c

# %%
type(L),type(L[0])
# Out:
# (list, str)

# %%
#indexing works the same as with string
L[-1],L[-2]
# Out:
# ('c', 'b')

# %%
L[1:3] #sublist starting at position 1 up to but not including position 3
# Out:
# ['b', 'c']

# %%
L[::2] #every other item
# Out:
# ['a', 'c']

# %% [markdown]
# You can put __anything__ in a list. Doesn't have to be same type

# %%
L=['cat', 9, 8, 7, 'dog', 3.1415]

# %%
type(L[0]),type(L[1])
# Out:
# (str, int)

# %%
#You can even do lists of lists
L=[[1,2,3],[4,5,6,]]
print(L)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
print(L[0])
# Out:
# [1, 2, 3]

# %% [markdown]
# __Constructing Lists__

# %%
#Method 1 - above
L=[1,2,3]
L
# Out:
# [1, 2, 3]

# %%
#Method 2- make list empty with [] add items with append
L=[]       
L.append(1)
L.append(2)
L.append(3)
L
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
#Method 3 -Spliting a string
s="If you can dodge a wrench, you can dodge a ball"
L=s.split()  #split defaults to splitting on spaces
L
# Out:
# ['If',
#  'you',
#  'can',
#  'dodge',
#  'a',
#  'wrench,',
#  'you',
#  'can',
#  'dodge',
#  'a',
#  'ball']

# %% [markdown]
# __Removing Items__

# %%
L=[3,2,3,2,3,2,3,2]
print(L)
L.remove(3)  #removes the first appearance of the number 3 
L
# Out:
# [3, 2, 3, 2, 3, 2, 3, 2]
# [2, 3, 2, 3, 2, 3, 2]

# %%
L.pop(2) #removes item in position 2
L
# Out:
# [2, 3, 3, 2, 3, 2]

# %%
L.insert(4,'cat') #inserts  'cat' into position 4
L
# Out:
# [2, 3, 3, 2, 'cat', 'cat', 3, 2]

# %%
#Can sort items with L.sort()
L=[1,2,3,4,2,3,4,5,2,3,4]
L.sort()     
L
# Out:
# [1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5]

# %%
#reverse items with L.reverse()
L.reverse()
L
# Out:
# [5, 4, 4, 4, 3, 3, 3, 2, 2, 2, 1]

# %% [markdown]
# __Fancier Sorting__

# %%
#You have my permission to stop typing here

L=[1,2,3,4,2,3,4,5,2,3,4]

#This is how you write functions in python. More on this later. (Don't worry!)
def is_odd(x):
    return x%2==1

#This puts all the even numbers first
L.sort(key=is_odd)
L
# Out:
# [2, 4, 2, 4, 2, 4, 1, 3, 3, 5, 3]

# %%
#We can do even better
L=[1,2,3,4,2,3,4,5,2,3,4]

def sorter(x):
    return(is_odd(x),x)

L.sort(key=sorter)
L
# Out:
# [2, 2, 2, 4, 4, 4, 1, 3, 3, 3, 5]
