# %% [markdown]
# # Selecting Rows
#
# In the last lecture, we saw how to extract specific columns from a data frame. In many cases, we also need to extract specific rows. This operation is often called "filtering" -- we are filtering out the rows that we don't want, leaving the ones that we do.

# %%
#standard imports - pandas and numpy
import pandas as pd
import numpy as np

# %% [markdown]
# From the last video, you should already have a file called palmer_penguins.csv in the same folder as this notebook. Please makesure this is case.
#
# __Now:__ let's read the csv into a dataframe

# %%
penguins=pd.read_csv("palmer_penguins.csv")

penguins.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %% [markdown]
# Let's restrict attention to only four columns: Species, Region, Island, and Culmen Length (mm)

# %%
cols=["Species","Region","Island","Culmen Length (mm)"]

penguins=penguins[cols]
#use .head() to only display the top five rows
penguins.head()
# Out:
#                                Species  Region     Island  Culmen Length (mm)
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                39.1
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                39.5
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                40.3
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                 NaN
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                36.7

# %% [markdown]
# The simplest way to select rows of data is by explicitly naming the value(s) of the index for the rows you want. Remember that the index is the set of bold numbers at the far left. To do this, you should use the `df.loc` attribute of the data frame, like this:

# %%
#rows one through three (note the end point IS included here)
penguins.loc[1:3]
# Out:
#                                Species  Region     Island  Culmen Length (mm)
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                39.5
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                40.3
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                 NaN

# %% [markdown]
# You can also select rows with a list

# %%
#subset of rows
rows=[1,4,0]
#store just those rows in a new dataframe
s=penguins.loc[rows]
s
# Out:
#                                Species  Region     Island  Culmen Length (mm)
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                39.5
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                36.7
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen                39.1

# %% [markdown]
# Note: Indexing is "Like a dict"

# %%
# note that this works, even though s does not have a 4th row, 
# because s does have an index with value 4
s.loc[4]
# Out:
# Species               Adelie Penguin (Pygoscelis adeliae)
# Region                                             Anvers
# Island                                          Torgersen
# Culmen Length (mm)                                   36.7
# Name: 4, dtype: object

# %%
# on the other hand, this doesn't work
s.loc[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-1d3ba2e47d68> in <module>
#       1 # on the other hand, this doesn't work
# ----> 2 s.loc[2]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 2

# %% [markdown]
# ## Boolean Indexing
#
# While it's good to know how to refer to rows by index, this is not the most useful way to filter data frames. Boolean indexing instead allows us to filter the rows of a data set based on one or more conditions. Boolean indexing in data frames is very similar to Boolean indexing in `numpy` arrays.

# %%
#Recall, our data looks like this 
penguins
# Out:
#                                  Species  Region     Island  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                   ...     ...        ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#      Culmen Length (mm)
# 0                  39.1
# 1                  39.5
# 2                  40.3
# 3                   NaN
# 4                  36.7
# ..                  ...
# 339                 NaN
# 340                46.8
# 341                50.4
# 342                45.2
# 343                49.9
#
# [344 rows x 4 columns]

# %% [markdown]
# Let's use boolean indexing to restrict attention to penguins with culmen length < 40

# %%
#create a mask
culmen_mask = penguins["Culmen Length (mm)"]<40
culmen_mask
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: Culmen Length (mm), Length: 344, dtype: bool

# %%
penguins[culmen_mask]
# Out:
#                                  Species  Region     Island  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 5    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 6    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                   ...     ...        ...
# 146  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 147  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 148  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 149  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 150  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
#
#      Culmen Length (mm)
# 0                  39.1
# 1                  39.5
# 4                  36.7
# 5                  39.3
# 6                  38.9
# ..                  ...
# 146                39.2
# 147                36.6
# 148                36.0
# 149                37.8
# 150                36.0
#
# [100 rows x 4 columns]

# %% [markdown]
# Now, let's restrict to penguins living on the Island Torgersen

# %%
#create a new mask
Island_mask=penguins["Island"]=="Torgersen"
#apply  boolean indexing
penguins[Island_mask]
# Out:
#                                  Species  Region     Island  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 5    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 6    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 7    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 8    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 9    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 10   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 11   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 12   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 13   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 14   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 15   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 16   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 17   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 18   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 19   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 68   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 69   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 70   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 71   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 72   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 73   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 74   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 75   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 76   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 77   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 78   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 79   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 80   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 81   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 82   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 83   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 116  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 117  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 118  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 119  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 120  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 121  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 122  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 123  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 124  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 125  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 126  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 127  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 128  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 129  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 130  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 131  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#      Culmen Length (mm)
# 0                  39.1
# 1                  39.5
# 2                  40.3
# 3                   NaN
# 4                  36.7
# 5                  39.3
# 6                  38.9
# 7                  39.2
# 8                  34.1
# 9                  42.0
# 10                 37.8
# 11                 37.8
# 12                 41.1
# 13                 38.6
# 14                 34.6
# 15                 36.6
# 16                 38.7
# 17                 42.5
# 18                 34.4
# 19                 46.0
# 68                 35.9
# 69                 41.8
# 70                 33.5
# 71                 39.7
# 72                 39.6
# 73                 45.8
# 74                 35.5
# 75                 42.8
# 76                 40.9
# 77                 37.2
# 78                 36.2
# 79                 42.1
# 80                 34.6
# 81                 42.9
# 82                 36.7
# 83                 35.1
# 116                38.6
# 117                37.3
# 118                35.7
# 119                41.1
# 120                36.2
# 121                37.7
# 122                40.2
# 123                41.4
# 124                35.2
# 125                40.6
# 126                38.8
# 127                41.5
# 128                39.0
# 129                44.1
# 130                38.5
# 131                43.1

# %% [markdown]
# Penguins that live on Torgersen and have short culmen. (You need & here, "and" doesn't work)

# %%
penguins[culmen_mask & Island_mask]
# Out:
#                                  Species  Region     Island  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 5    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 6    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 7    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 8    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 10   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 11   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 13   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 14   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 15   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 16   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 18   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 68   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 70   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 71   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 72   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 74   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 77   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 78   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 80   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 82   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 83   Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 116  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 117  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 118  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 120  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 121  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 124  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 126  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 128  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 130  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#      Culmen Length (mm)
# 0                  39.1
# 1                  39.5
# 4                  36.7
# 5                  39.3
# 6                  38.9
# 7                  39.2
# 8                  34.1
# 10                 37.8
# 11                 37.8
# 13                 38.6
# 14                 34.6
# 15                 36.6
# 16                 38.7
# 18                 34.4
# 68                 35.9
# 70                 33.5
# 71                 39.7
# 72                 39.6
# 74                 35.5
# 77                 37.2
# 78                 36.2
# 80                 34.6
# 82                 36.7
# 83                 35.1
# 116                38.6
# 117                37.3
# 118                35.7
# 120                36.2
# 121                37.7
# 124                35.2
# 126                38.8
# 128                39.0
# 130                38.5

# %% [markdown]
# Penguins that live on Torgersen or have short culmen. (Use bitwise or operator | not "or)

# %%
penguins[culmen_mask | Island_mask]
# Out:
#                                  Species  Region     Island  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                   ...     ...        ...
# 146  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 147  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 148  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 149  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 150  Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
#
#      Culmen Length (mm)
# 0                  39.1
# 1                  39.5
# 2                  40.3
# 3                   NaN
# 4                  36.7
# ..                  ...
# 146                39.2
# 147                36.6
# 148                36.0
# 149                37.8
# 150                36.0
#
# [119 rows x 4 columns]

# %% [markdown]
# ## Getting rid of nan's

# %%
# The function .isna() return true if an entry is a nan 
nans=penguins["Culmen Length (mm)"].isna()
#Here are the entries with nan's in the culmen length

penguins[nans]
# Out:
#                                  Species  Region     Island  \
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#      Culmen Length (mm)
# 3                   NaN
# 339                 NaN

# %% [markdown]
# Typically, we want to look at all of the entries WITHOUT nans

# %%
penguins=penguins[np.invert(nans)]

# %%
penguins.shape
# Out:
# (342, 4)
